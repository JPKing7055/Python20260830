# %% [markdown]
# <a href="https://colab.research.google.com/github/JPKing7055/Python20260830/blob/main/FirstColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 3
print(a)
# Out:
# 3

# %%
print(a+2)
# Out:
# 5
